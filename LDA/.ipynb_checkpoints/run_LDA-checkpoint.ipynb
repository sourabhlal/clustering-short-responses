# %% [markdown]
# Read list of tags from file

# %%
with open("../moocs_tags", "r") as f:
    content = f.readlines()

# %% [markdown]
# Helper Function for cleaning text

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# %%
doc_c = [clean(doc) for doc in content]   
doc_clean = [doc.split() for doc in doc_c]

# %% [markdown]
# Create Document-Term Matrix

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our courpus, where every unique term is assigned an index.

dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %% [markdown]
# Train LDA model using Document-Term Matrix

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=100, id2word = dictionary, passes=50)

# %% [markdown]
# List of topics generated using LDA

# %%
ldamodel.print_topics(num_topics=100, num_words=5)
# Out:
# [(0,
#   '0.108*"new" + 0.062*"security" + 0.046*"network" + 0.031*"tech" + 0.031*"indigenous"'),
#  (1,
#   '0.093*"professional" + 0.054*"dynamic" + 0.040*"self" + 0.040*"blended" + 0.027*"poetry"'),
#  (2,
#   '0.235*"teach" + 0.211*"english" + 0.196*"moral" + 0.016*"pi" + 0.016*"raspberry"'),
#  (3,
#   '0.090*"environment" + 0.064*"presentation" + 0.039*"word" + 0.039*"marketing" + 0.039*"informal"'),
#  (4,
#   '0.309*"nanotechnology" + 0.037*"question" + 0.013*"mathchat" + 0.013*"lm" + 0.013*"photosynthesis"'),
#  (5,
#   '0.538*"skill" + 0.025*"renewable" + 0.008*"generation" + 0.008*"next" + 0.008*"source"'),
#  (6,
#   '0.101*"french" + 0.076*"instruction" + 0.063*"maker" + 0.051*"junior" + 0.038*"test"'),
#  (7,
#   '0.315*"education" + 0.170*"physic" + 0.124*"administration" + 0.107*"operation" + 0.107*"civic"'),
#  (8,
#   '0.302*"general" + 0.108*"literature" + 0.097*"middle" + 0.022*"taxonomy" + 0.022*"open"'),
#  (9,
#   '0.080*"motion" + 0.064*"architecture" + 0.048*"philippine" + 0.048*"20" + 0.032*"quantum"'),
#  (10,
#   '0.359*"technology" + 0.177*"game" + 0.159*"innovation" + 0.082*"high" + 0.006*"animation"'),
#  (11,
#   '0.227*"ict" + 0.219*"quality" + 0.188*"postharvest" + 0.016*"evaluation" + 0.008*"point"'),
#  (12,
#   '0.136*"baking" + 0.136*"edutainment" + 0.136*"bellas" + 0.136*"tefl" + 0.136*"artes"'),
#  (13,
#   '0.088*"technical" + 0.088*"career" + 0.074*"virtual" + 0.059*"tourism" + 0.044*"cambridge"'),
#  (14,
#   '0.288*"study" + 0.247*"health" + 0.185*"public" + 0.007*"particle" + 0.007*"foreigner"'),
#  (15,
#   '0.310*"biology" + 0.183*"century" + 0.176*"21st" + 0.014*"chain" + 0.007*"room"'),
#  (16,
#   '0.198*"business" + 0.116*"international" + 0.082*"project" + 0.023*"listening" + 0.023*"coding"'),
#  (17,
#   '0.196*"senior" + 0.188*"art" + 0.188*"colour" + 0.016*"latin" + 0.008*"momentum"'),
#  (18,
#   '0.467*"biotechnology" + 0.019*"pressure" + 0.019*"living" + 0.019*"fluid" + 0.010*"infused"'),
#  (19,
#   '0.133*"inquiry" + 0.100*"online" + 0.056*"elearning" + 0.056*"special" + 0.045*"coach"'),
#  (20,
#   '0.179*"development" + 0.060*"dentistry" + 0.060*"problem" + 0.045*"evidence" + 0.015*"collabo"'),
#  (21,
#   '0.202*"adolescent" + 0.194*"leader" + 0.194*"vulnarable" + 0.016*"native" + 0.016*"intelligent"'),
#  (22,
#   '0.235*"de" + 0.188*"medios" + 0.188*"comunicación" + 0.008*"universidad" + 0.008*"nuevo"'),
#  (23,
#   '0.334*"cambraia" + 0.028*"tutor" + 0.028*"arabic" + 0.028*"experiential" + 0.014*"productivity"'),
#  (24,
#   '0.071*"plant" + 0.057*"growth" + 0.057*"medicine" + 0.057*"function" + 0.042*"alternative"'),
#  (25,
#   '0.216*"social" + 0.125*"training" + 0.046*"civilization" + 0.034*"active" + 0.023*"justice"'),
#  (26,
#   '0.388*"strategy" + 0.013*"variable" + 0.013*"zealand" + 0.013*"mediation" + 0.013*"mindfulness"'),
#  (27,
#   '0.061*"leadership" + 0.061*"law" + 0.061*"reaction" + 0.046*"citizenship" + 0.046*"developmental"'),
#  (28,
#   '0.177*"dance" + 0.170*"photograpy" + 0.170*"li" + 0.170*"28" + 0.007*"twitter"'),
#  (29,
#   '0.577*"chemistry" + 0.017*"soil" + 0.017*"advisor" + 0.009*"one" + 0.009*"care"'),
#  (30,
#   '0.278*"green" + 0.111*"energy" + 0.056*"resource" + 0.022*"classical" + 0.022*"ed"'),
#  (31,
#   '0.602*"art" + 0.041*"electrical" + 0.033*"library" + 0.008*"aerospace" + 0.008*"industry"'),
#  (32,
#   '0.204*"industrial" + 0.204*"documentation" + 0.195*"pedagogical" + 0.024*"device" + 0.016*"electrical"'),
#  (33,
#   '0.429*"student" + 0.231*"esl" + 0.027*"course" + 0.020*"tesol" + 0.014*"division"'),
#  (34,
#   '0.582*"early" + 0.062*"culture" + 0.023*"european" + 0.016*"prealgebra" + 0.008*"ebusiness"'),
#  (35,
#   '0.586*"learning" + 0.086*"brain" + 0.080*"deep" + 0.080*"elderly" + 0.010*"change"'),
#  (36,
#   '0.278*"craft" + 0.172*"curriculum" + 0.150*"making" + 0.139*"waste" + 0.011*"u"'),
#  (37,
#   '0.363*"school" + 0.141*"secondary" + 0.138*"science" + 0.118*"natural" + 0.009*"la"'),
#  (38,
#   '0.225*"video" + 0.194*"gear" + 0.186*"tutorial" + 0.016*"minecraft" + 0.016*"calculus"'),
#  (39,
#   '0.202*"age" + 0.167*"kocw" + 0.167*"speech" + 0.167*"old" + 0.014*"genetics"'),
#  (40,
#   '0.281*"communication" + 0.225*"design" + 0.065*"information" + 0.028*"production" + 0.019*"wave"'),
#  (41,
#   '0.312*"democracy" + 0.039*"cycle" + 0.026*"vocational" + 0.026*"bible" + 0.026*"mammal"'),
#  (42,
#   '0.064*"knowledge" + 0.064*"core" + 0.048*"experiment" + 0.032*"cross" + 0.032*"purpose"'),
#  (43,
#   '0.103*"foreign" + 0.044*"theatre" + 0.044*"material" + 0.030*"cost" + 0.030*"sci"'),
#  (44,
#   '0.203*"artes" + 0.110*"chinese" + 0.101*"visuales" + 0.101*"8ª" + 0.101*"plasticas"'),
#  (45,
#   '0.652*"management" + 0.015*"urban" + 0.008*"estatística" + 0.008*"swtiching" + 0.008*"nuclear"'),
#  (46,
#   '0.450*"elementary" + 0.030*"specialist" + 0.030*"circuit" + 0.020*"consultant" + 0.020*"québec"'),
#  (47,
#   '0.087*"academic" + 0.058*"geometry" + 0.058*"3" + 0.044*"classroom" + 0.044*"prep"'),
#  (48,
#   '0.294*"child" + 0.275*"mechanic" + 0.039*"preschool" + 0.020*"liberal" + 0.010*"kinder"'),
#  (49,
#   '0.119*"analysis" + 0.083*"work" + 0.072*"medical" + 0.060*"force" + 0.048*"society"'),
#  (50,
#   '0.280*"ccls" + 0.197*"writing" + 0.012*"cellular" + 0.012*"unit" + 0.012*"write"'),
#  (51,
#   '0.435*"science" + 0.251*"history" + 0.032*"earth" + 0.032*"american" + 0.016*"contest"'),
#  (52,
#   '0.183*"ecology" + 0.169*"slang" + 0.169*"psycholinguistics" + 0.169*"homework" + 0.007*"wordpress"'),
#  (53,
#   '0.256*"computer" + 0.061*"8" + 0.049*"kid" + 0.037*"sound" + 0.037*"integrated"'),
#  (54,
#   '0.054*"phonetics" + 0.036*"montessori" + 0.036*"postgraduate" + 0.036*"talk" + 0.036*"neuroscience"'),
#  (55,
#   '0.379*"fish" + 0.357*"english" + 0.010*"smart" + 0.005*"machinery" + 0.005*"grid"'),
#  (56,
#   '0.359*"economics" + 0.026*"programing" + 0.026*"technicaldraw" + 0.013*"everyday" + 0.013*"ibst"'),
#  (57,
#   '0.221*"german" + 0.137*"food" + 0.106*"technology" + 0.106*"khan" + 0.106*"copy"'),
#  (58,
#   '0.309*"comic" + 0.050*"nature" + 0.037*"physical" + 0.037*"honor" + 0.013*"ipad"'),
#  (59,
#   '0.507*"year" + 0.162*"framework" + 0.034*"5" + 0.007*"85" + 0.007*"wiris"'),
#  (60,
#   '0.133*"human" + 0.084*"global" + 0.060*"economy" + 0.036*"physiology" + 0.036*"band"'),
#  (61,
#   '0.289*"geography" + 0.248*"didactics" + 0.021*"fashion" + 0.021*"app" + 0.010*"number"'),
#  (62,
#   '0.086*"university" + 0.072*"method" + 0.072*"power" + 0.043*"oral" + 0.043*"electronics"'),
#  (63,
#   '0.255*"psychology" + 0.220*"cultural" + 0.044*"apps" + 0.026*"voice" + 0.026*"undergraduate"'),
#  (64,
#   '0.390*"educational" + 0.185*"robotics" + 0.057*"classroom" + 0.014*"c" + 0.014*"logic"'),
#  (65,
#   '0.241*"agriculture" + 0.223*"gardening" + 0.037*"understanding" + 0.028*"mobile" + 0.019*"ib"'),
#  (66,
#   '0.141*"google" + 0.129*"research" + 0.047*"integration" + 0.047*"life" + 0.035*"learner"'),
#  (67,
#   '0.341*"creative" + 0.023*"texas" + 0.023*"collaboration" + 0.023*"instrument" + 0.012*"content"'),
#  (68,
#   '0.200*"mathematics" + 0.080*"applied" + 0.040*"2" + 0.040*"assisted" + 0.040*"workshop"'),
#  (69,
#   '0.099*"web" + 0.071*"equation" + 0.057*"7" + 0.042*"drawing" + 0.028*"45"'),
#  (70,
#   '0.148*"first" + 0.128*"still" + 0.123*"learning" + 0.123*"already" + 0.123*"im"'),
#  (71,
#   '0.053*"k5" + 0.035*"control" + 0.035*"pyp" + 0.035*"pe" + 0.035*"orthodontics"'),
#  (72,
#   '0.288*"music" + 0.212*"drama" + 0.046*"emotional" + 0.015*"moodle" + 0.015*"biological"'),
#  (73,
#   '0.317*"product" + 0.026*"metrology" + 0.026*"mexico" + 0.013*"reliever" + 0.013*"geometrical"'),
#  (74,
#   '0.334*"adult" + 0.042*"spanish" + 0.042*"programming" + 0.021*"roman" + 0.021*"young"'),
#  (75,
#   '0.356*"processing" + 0.053*"safety" + 0.027*"heat" + 0.013*"potato" + 0.013*"temperature"'),
#  (76,
#   '0.207*"katialucia" + 0.207*"11math" + 0.207*"mindmapping" + 0.017*"simulation" + 0.009*"cyber"'),
#  (77,
#   '0.304*"basic" + 0.151*"reading" + 0.051*"graphic" + 0.030*"novel" + 0.020*"exam"'),
#  (78,
#   '0.661*"language" + 0.060*"second" + 0.011*"geological" + 0.011*"musicology" + 0.006*"dista"'),
#  (79,
#   '0.385*"design" + 0.183*"digital" + 0.125*"preparation" + 0.116*"electronic" + 0.014*"instructional"'),
#  (80,
#   '0.178*"teacher" + 0.128*"celta" + 0.109*"education" + 0.101*"painting" + 0.097*"portuguese"'),
#  (81,
#   '0.116*"world" + 0.105*"process" + 0.070*"theory" + 0.035*"greek" + 0.035*"creativity"'),
#  (82,
#   '0.080*"matter" + 0.064*"internet" + 0.064*"1" + 0.048*"canada" + 0.032*"mechanical"'),
#  (83,
#   '0.202*"organic" + 0.194*"synthesis" + 0.024*"computing" + 0.016*"learn" + 0.016*"drive"'),
#  (84,
#   '0.203*"based" + 0.089*"assessment" + 0.051*"application" + 0.038*"standard" + 0.026*"consumer"'),
#  (85,
#   '0.051*"gafe" + 0.051*"educator" + 0.034*"contemporary" + 0.034*"thermal" + 0.017*"department"'),
#  (86,
#   '0.122*"college" + 0.086*"activity" + 0.073*"software" + 0.037*"distance" + 0.037*"water"'),
#  (87,
#   '0.604*"fishery" + 0.008*"epistemology" + 0.008*"minded" + 0.008*"solubility" + 0.008*"hospitality"'),
#  (88,
#   '0.323*"grammar" + 0.078*"chemical" + 0.045*"ancient" + 0.022*"calculation" + 0.022*"hand"'),
#  (89,
#   '0.182*"literacy" + 0.091*"ap" + 0.052*"6" + 0.026*"low" + 0.026*"independent"'),
#  (90,
#   '0.279*"math" + 0.194*"visual" + 0.122*"thinking" + 0.090*"value" + 0.086*"singapore"'),
#  (91,
#   '0.313*"teaching" + 0.275*"structure" + 0.039*"interactive" + 0.020*"setting" + 0.010*"prac"'),
#  (92,
#   '0.338*"kindergarten" + 0.081*"issue" + 0.054*"practical" + 0.027*"linguistics" + 0.014*"teen"'),
#  (93,
#   '0.241*"book" + 0.232*"egypt" + 0.056*"data" + 0.028*"population" + 0.019*"number"'),
#  (94,
#   '0.092*"efl" + 0.062*"machine" + 0.062*"4" + 0.046*"measurement" + 0.031*"area"'),
#  (95,
#   '0.275*"engineering" + 0.216*"medium" + 0.141*"competence" + 0.141*"agricultural" + 0.006*"envoronmental"'),
#  (96,
#   '0.231*"grade" + 0.172*"system" + 0.060*"algebra" + 0.045*"9" + 0.037*"instrumentation"'),
#  (97,
#   '0.238*"biocomp" + 0.238*"ele" + 0.030*"electricity" + 0.020*"construction" + 0.020*"addition"'),
#  (98,
#   '0.398*"class" + 0.034*"stem" + 0.023*"linear" + 0.023*"relation" + 0.012*"problembased"'),
#  (99,
#   '0.146*"eletricity" + 0.146*"homeschooling" + 0.146*"tradition" + 0.146*"diseño" + 0.146*"heba"')]

# %% [markdown]
# Seeing topic assigned to document 0 with probability

# %%
ldamodel.get_document_topics(dictionary.doc2bow(doc_clean[0]))
# Out:
# [(93, 0.50499999999999978)]

# %% [markdown]
# Looping though all documents to get their list of topics. Adding each document to cluster based on the most likely topic. Printing out list of clusters in the end.

# %%
clusters = [[] for i in range(100)]
for idx,doc_i in enumerate(doc_clean):
    score = ldamodel.get_document_topics(dictionary.doc2bow(doc_i))
    if len(score) > 0 :
        bucket = max(ldamodel.get_document_topics(dictionary.doc2bow(doc_i)), key=lambda x: x[1])[0]
        score = max(ldamodel.get_document_topics(dictionary.doc2bow(doc_i)), key=lambda x: x[1])[1]
        if score > 0.5:
            clusters[bucket].append(doc_c[idx])
clusters
# Out:
# [['network',
#   'gas atmospheric chemistry',
#   'new headway',
#   'small active cute',
#   'indigenous',
#   'network security',
#   'security',
#   'organization',
#   'politcs',
#   'specie',
#   'arduino',
#   '46'],
#  ['poetry',
#   'steam',
#   'accounting',
#   'dynamic',
#   'parent',
#   '3d cad',
#   'blended',
#   'misconception',
#   'beforeschool',
#   'professional ethic',
#   'adhd',
#   'transdisciplinarity',
#   'museology',
#   'dynamic',
#   'cad',
#   'trigonometry',
#   'gender'],
#  ['human right responsibility',
#   'teenager',
#   'raspberry pi',
#   'english camp',
#   'moral',
#   'fgv',
#   'learn teach english',
#   'raspberry pi platform'],
#  ['marketing',
#   'human impact environment',
#   'word way',
#   'transdisciplinary',
#   'key stage 3',
#   'key stage 4',
#   'key stage 5',
#   'environment',
#   '512',
#   'environment',
#   'presentation',
#   'informal',
#   'militar',
#   'lengua franca',
#   'interesting presentation',
#   'esol',
#   'superlogo',
#   'presentation'],
#  ['photosynthesis',
#   'discourse',
#   'biophysics',
#   'metalwork',
#   'ibpyp',
#   'microteaching',
#   'lm',
#   'precalculus',
#   'mathchat',
#   'question',
#   'storytelling',
#   'nanotechnology gene technology',
#   'cyberespace',
#   'question tool',
#   'microeconomics',
#   'raciocínio lógico'],
#  ['accountancy',
#   'fractal',
#   'administrator',
#   'rendering',
#   'artifact',
#   'certification',
#   'motivation',
#   'legal reasoning',
#   'gamification',
#   'skill building',
#   'renewable non renewable energy source',
#   'kinematics'],
#  ['space',
#   'shakespeare',
#   'movement',
#   'volumebyslicing',
#   'maker movement',
#   'french',
#   'automobile',
#   'debate',
#   'junior french',
#   'filmmaking',
#   'uae',
#   'mythology folklore',
#   'standardized test skill',
#   'reggio',
#   'test',
#   'biochemistry',
#   'counseling',
#   'maker',
#   'lenguage',
#   'volunteering',
#   'maker space'],
#  ['physic',
#   'sex education',
#   'civic education',
#   'education',
#   'physic',
#   'physic education',
#   'botany',
#   'administration',
#   'livescribe pen',
#   'geometer sketchpad',
#   'multimodatity'],
#  ['literature',
#   'asia',
#   'bloom taxonomy',
#   'hxkj',
#   'taxonomy',
#   'open middle',
#   'literature',
#   'subsutitute teache',
#   'connectivism',
#   'general',
#   'digitalinclusion'],
#  ['architecture',
#   'architecture',
#   '20',
#   'philippine',
#   'toxicology',
#   'motion',
#   'masen',
#   'web 20 tool',
#   'gravity',
#   'dysgraphia',
#   'educação inovação tecnologia aprendizagem',
#   'thermodynamics',
#   'interior architecture',
#   'ipv6'],
#  ['innovation',
#   'technology',
#   'k4',
#   'game',
#   'silhouette animation',
#   'technology',
#   'geotech'],
#  ['quadratic formula',
#   'gi',
#   'ict',
#   'myp',
#   'quality assurance',
#   'ict',
#   'fe',
#   'afterschool',
#   'evaluation',
#   'matlab',
#   'quality',
#   '123',
#   'postharvest'],
#  ['sharing',
#   'lexia',
#   'hardware',
#   'multigrade',
#   'individulization',
#   'advance placement',
#   'baking',
#   'edutainment',
#   'bellas artes',
#   'tefl'],
#  ['career',
#   'differentiation',
#   'multimedia',
#   'artebrasil',
#   'team building',
#   'modeling',
#   'career technical education',
#   'tourism',
#   'workplace',
#   'career technical'],
#  ['health',
#   'variability',
#   'public health issue',
#   'allied health',
#   'astronomy',
#   'public health',
#   'pathology',
#   'inclusion',
#   'health study'],
#  ['biology',
#   'evaluate',
#   'letter',
#   'biology',
#   'eclass room',
#   'udl',
#   'transcultural musicology',
#   'laboratory',
#   '21st century skill'],
#  ['international business',
#   'stoichiometry',
#   'project',
#   'business',
#   'international',
#   'engineer without border',
#   'listening',
#   'coding',
#   'coding',
#   'animation',
#   'mathscience',
#   'maori',
#   'prehistory',
#   'spanishlanguage',
#   'geogrphay',
#   'alice'],
#  ['engine',
#   'eld',
#   'leadeship',
#   'latin',
#   'schoolage',
#   'eal',
#   'senior',
#   'latin',
#   'entr',
#   'evolutionary musicology',
#   'religiouseducation',
#   'programação',
#   'boon bane'],
#  ['living thing',
#   'fluid',
#   'sequence series',
#   'biotechnology',
#   '912',
#   'welding',
#   'holistic',
#   'metaphysics',
#   'pressure',
#   'fluid pressure',
#   'horticulture',
#   'zoology',
#   'phd',
#   'combinatorics'],
#  ['elearning',
#   'special relativity',
#   'statistic',
#   'innovative',
#   'elearning',
#   'elearning environmnet',
#   'rock mineral',
#   'innovative',
#   'india',
#   'inquiry approach',
#   'pedagogy',
#   'd2l elearning chemistry',
#   'inquiry',
#   'online',
#   'inquiry',
#   'statistic pedagogy online learning authentic inquiry learning',
#   'authentic',
#   'coach'],
#  ['evidence',
#   'finite element method',
#   'evidence based dentistry',
#   'dentistry',
#   'collabo',
#   'dentistry',
#   'piano',
#   'electromagnetism',
#   'development',
#   'complexity',
#   'montreal'],
#  ['optic',
#   'coastal navigation',
#   'univesity',
#   'california native american',
#   'multiple intelligent',
#   'emotion',
#   'instrumental',
#   'mixed ability',
#   'jazz',
#   'adolescent',
#   'puppet',
#   'leader',
#   'vulnarable adolescent'],
#  ['gt',
#   'php',
#   '179',
#   'outreach',
#   'andragogy',
#   'oceanography',
#   'teach biochemistry molecular biology course medical student school medicine universidad autonoma de nuevo leon',
#   'prekinder',
#   'medios de comunicación'],
#  ['atom element compound',
#   'experiential',
#   'tutor',
#   'productivity',
#   'litreture',
#   'onlinelearning',
#   'arabic',
#   'cambraia'],
#  ['plant growth change',
#   'medicine',
#   'plant',
#   'function',
#   'plant anatomy growth function',
#   'anatomy',
#   'contract',
#   'sat subject test',
#   'sat',
#   'rhino 3d',
#   'medicine',
#   'matheducator',
#   'alternative',
#   'abstract',
#   'eslefl',
#   'diversity'],
#  ['social justice',
#   'western civilization',
#   'front office',
#   'training',
#   'ece',
#   'active method',
#   'social justice science',
#   'teacher training institute',
#   'civilization',
#   'tsunami',
#   'ec',
#   'romanian',
#   'e'],
#  ['variable',
#   'mindfulness',
#   'strategy',
#   'song',
#   'teeth',
#   'autonomy',
#   'choir',
#   'coteaching',
#   'igcce program',
#   'earthquake',
#   'ffsfd',
#   'strategy',
#   'mediation'],
#  ['std',
#   'politics',
#   'law',
#   'citizenship',
#   'rate reaction',
#   'woodwork',
#   'commercial law',
#   'journalism',
#   'terminology',
#   'italian',
#   'leadership',
#   'internacio',
#   'italian'],
#  ['flight',
#   'dialogue',
#   'dance',
#   'choral',
#   'oralmedicine',
#   'physiotherapy',
#   'onetoone',
#   'cefr',
#   'twitter',
#   'magda',
#   'zoliti',
#   '28',
#   'photograpy',
#   'li'],
#  ['soil',
#   'artandvisualculture',
#   'musica',
#   'chemistry',
#   'diagram',
#   'aim',
#   'accessability',
#   'chemistry',
#   'korean',
#   'one child policy',
#   'paleontology'],
#  ['conservation energy resource',
#   'robot',
#   'energy',
#   'energy change',
#   'conservation',
#   'green building',
#   'quebec',
#   'resource',
#   'grafica funciones de distinto grado',
#   'concept'],
#  ['parabola',
#   'library',
#   'art',
#   'art',
#   'instrumentation aerospace industry',
#   'library',
#   'art handcraft',
#   'wellness',
#   'humanitarian'],
#  ['electricity electrical device',
#   'javascript',
#   'lucy cawkins',
#   'electrical measurement device',
#   'rpgs',
#   'autism',
#   'map',
#   'kin',
#   'luciana',
#   'pedagogical documentation'],
#  ['esl',
#   'room division',
#   '178',
#   'aplicaciones propiedades de los triangulos',
#   'division',
#   'tesol',
#   'esl',
#   'esl tesol',
#   'course',
#   'tesol'],
#  ['enriched prealgebra',
#   'prealgebra',
#   'culture',
#   'gcse',
#   'european culture',
#   'aging memory',
#   'ebusiness',
#   'uoa lecturer'],
#  ['animal growth change',
#   'pure substance',
#   'ethic',
#   'collaborative learning',
#   'urbanplanning',
#   'learning',
#   'educat',
#   'ethic',
#   'change',
#   'learning brain',
#   'learning',
#   'html5',
#   'p',
#   'accessory',
#   'deep learning',
#   'elderly learning',
#   'brain'],
#  ['making',
#   'reducing managing waste',
#   'waterresources',
#   'efi',
#   'craft making',
#   'curriculum',
#   'economic development indicator',
#   'differentiated curriculum',
#   'habitat',
#   'prbl',
#   'tablet',
#   'surrealism',
#   'craft'],
#  ['multiplication',
#   'season',
#   'city',
#   'secondary',
#   'climatechange',
#   'epidemiology',
#   'storybird',
#   'art secondary school',
#   'numeracy',
#   'aplicaciones de la fisica en la tecnologia actual',
#   'garden',
#   'middle school science',
#   'school garden',
#   'secondary science method',
#   'secondary school',
#   'natural science'],
#  ['pulley gear',
#   'quantity',
#   'immunology',
#   'minecraft',
#   '12',
#   'dental',
#   'behavior',
#   'calculus',
#   'video',
#   'minecraft',
#   'ab calculus',
#   'behavior disorder',
#   'ako',
#   'video tutorial'],
#  ['entrepreneurship',
#   'molecular genetics',
#   'probability',
#   'genetics',
#   'constuctive',
#   'improvisation',
#   'modern age',
#   '1705',
#   'kocw',
#   'old age learning',
#   'speech'],
#  ['information communication technology',
#   'information communication technology',
#   'production',
#   'sing',
#   'l',
#   'communication',
#   'eresources',
#   'belief',
#   'vietnamese',
#   'coaching',
#   'genius hour',
#   'visual communication design'],
#  ['rock cycle',
#   'graphing',
#   'poland',
#   'love learn',
#   'bible',
#   'poverty',
#   'vocational',
#   'bible',
#   'biogeochemical cycle',
#   'mammal',
#   'photoshop',
#   'vertical surface',
#   'democracy'],
#  ['experiment',
#   'cross curricular',
#   'experiment',
#   'grade1',
#   'sla',
#   'homeschool',
#   'nc prek',
#   'core knowledge',
#   'planning',
#   'english specific purpose',
#   'plastic surgery'],
#  ['material',
#   'scratch',
#   'math tec sci',
#   'science fair supervisor',
#   'gmail',
#   'aurora',
#   'low cost non cost material teaching science',
#   'multiage',
#   'coordination',
#   'lake',
#   'moocs',
#   'macroeconomics',
#   'theatre',
#   'brasil'],
#  ['government',
#   'mandarin chinese',
#   'level',
#   'chinese',
#   'bird',
#   'tok',
#   '8ª serie',
#   'artes visuales',
#   'artes plasticas',
#   '10informatics'],
#  ['urban',
#   'management',
#   'estatística',
#   'shire',
#   'startup',
#   'event management',
#   'ecommerce',
#   'scale',
#   'pm',
#   'nuclear',
#   'swtiching'],
#  ['elementary',
#   'elementary science specialist',
#   'bioinformatics',
#   'elementary subject',
#   'elementary ethic',
#   'consultant',
#   'québec',
#   'olympiad',
#   'hereditability',
#   'java',
#   'elementary k8 consultant'],
#  ['gifted',
#   'argumentation',
#   '3',
#   'geometry k12 derivative integral',
#   'flipped classroom',
#   'geometry',
#   'geometry',
#   'byod',
#   'communitycollege',
#   'byod classroom',
#   'uptraining',
#   'china',
#   'flipped classroom'],
#  ['preschool',
#   'mechanic',
#   'child',
#   'publishing',
#   'preschool kinder',
#   'didatics'],
#  ['civics',
#   'force',
#   'analysis',
#   'work force',
#   'cinema',
#   'turkey',
#   'signal analysis',
#   'mooc',
#   'error analysis',
#   'volcano',
#   'society',
#   'signal analysis medical engineering',
#   'forest',
#   'database',
#   'group work activity'],
#  ['polynomial',
#   'conic section',
#   'writing',
#   'esthetic',
#   'sociology',
#   'cpm',
#   'google read write extension',
#   'settlement',
#   'ccls'],
#  ['american music history',
#   'history',
#   'science',
#   'earth science',
#   'homeostasis',
#   'copyright',
#   'science contest',
#   'resilience topic',
#   'science',
#   'science experiements',
#   'american history',
#   'subsea',
#   'el',
#   'history',
#   'contest',
#   'autoestima',
#   'history science'],
#  ['ecology',
#   'wordpress',
#   'ecology',
#   'grade2',
#   'minecraftedu',
#   'videomaker',
#   'tasc',
#   'adaptation scolaire',
#   'optimization',
#   'ethnomusicology',
#   'psycholinguistics',
#   'homework',
#   'slang'],
#  ['humanity',
#   'light sound',
#   'advertising',
#   'spreadsheet',
#   'sound',
#   'light',
#   '8',
#   'freshman',
#   'edtech',
#   'computer class kid',
#   'computer',
#   'kid',
#   'soccer',
#   'integrated humanity'],
#  ['powerpoint',
#   'neuroscience',
#   'lab instructor',
#   'accountable talk',
#   'uk',
#   'montessori',
#   'phonetics',
#   'supply demand'],
#  ['english languaje',
#   'ecosystem',
#   'reflection',
#   'english',
#   'english',
#   'smart',
#   'maya',
#   'lyceum',
#   'jehovah witness',
#   'fish',
#   'pyschology',
#   'machinery',
#   'smart grid',
#   'non profit organisation teaching'],
#  ['technicaldraw',
#   'fea',
#   'classical civilisation',
#   'ibst',
#   'economics',
#   'bitcoin',
#   'nmr spectroscopy',
#   'shape',
#   'labview programing'],
#  ['nutrition',
#   'compositionliterature',
#   'facilitating',
#   'subtraction without borrowing',
#   'lab',
#   'lab',
#   'subtraction',
#   'theology',
#   'food nutrition',
#   'makerspace',
#   'remote lab',
#   'copy khan academy german elementary school',
#   'food technology'],
#  ['tb',
#   'money',
#   'reinforcement',
#   'aesthetic',
#   'tinkering',
#   'executive functioning',
#   'ged',
#   'nature',
#   'engaged',
#   'skype',
#   'ipad',
#   'comic'],
#  ['phy',
#   '5',
#   'dialect',
#   'wiris',
#   'applet',
#   'asd',
#   'needgreater',
#   'europe',
#   '85',
#   'computação'],
#  ['physiology',
#   'biodiversity',
#   'economy',
#   'aquaculture',
#   'hindi',
#   'band',
#   'bansho',
#   'transmedia',
#   'propiedades de la potenciacion',
#   'tbl',
#   'human anatomy physiology',
#   'beginning band',
#   'christian',
#   'beginner',
#   'anatomy physiology',
#   'economy',
#   'oregon duck',
#   'spanishteacher',
#   'quadratic'],
#  ['keyboarding',
#   'telecommunication',
#   'geography',
#   'number sense',
#   'app geography',
#   'fashion',
#   'valores',
#   'didactics geography'],
#  ['electronics',
#   'pharmacy',
#   'university professor',
#   'numerical method',
#   'drupal',
#   'frações',
#   'power electronics',
#   'compositon',
#   'crosscurricular',
#   'university',
#   'reform',
#   '23',
#   'oral maxillofacial surgery'],
#  ['window',
#   'psychology',
#   'pharmacovigilance',
#   'voice text',
#   'text voice',
#   'diffusion osmosis',
#   'americanliterature multiculturalliterature writing essay researchpapers psychology englishlit',
#   'l2',
#   'mathphychem',
#   'cultural psychology'],
#  ['proof',
#   'robotics',
#   'logic',
#   'guidance',
#   'c',
#   'flipping classroom',
#   'c',
#   'coffee',
#   'educational platform',
#   'educational',
#   'robotics maker logic program',
#   'occupational therapy',
#   'educational robotics'],
#  ['clil',
#   'greenhouse gas',
#   'electrochemistry',
#   'agriculture forestry',
#   'ib',
#   'enthusiastic',
#   'agriculture',
#   'journey',
#   'mobile',
#   'ib diploma',
#   'unix',
#   'simulaciones de la conceptos fisicos',
#   'understanding',
#   'mobile',
#   'wananga',
#   'gardening agriculture'],
#  ['cell',
#   'negative number',
#   'integration',
#   'designbased research',
#   'research',
#   'avant garde',
#   'ipads',
#   'weak learner',
#   'sport',
#   'google',
#   'adultlearning',
#   'metacognition',
#   'google cloud',
#   'spelling',
#   'google addwords',
#   'cou'],
#  ['vector',
#   'teamwork',
#   'instrument',
#   'mysticism',
#   'istation',
#   'igcse',
#   'collaboration',
#   'critical creative thinking',
#   'show know',
#   'texas',
#   'empowering',
#   'texas instrument gdcs',
#   'lecture content',
#   'yearbook',
#   'informática na educação',
#   'creative'],
#  ['decimal',
#   'applied mathematics',
#   'mathematics',
#   'task',
#   'workshop',
#   '2',
#   'illustration',
#   'applied',
#   'applied',
#   'naturalist',
#   'every moment lesson'],
#  ['hydraulic pneumatic system',
#   'equation',
#   '7',
#   'dfferential equation',
#   'drawing',
#   'geogebra',
#   'dna',
#   'web developer',
#   'web quest',
#   'maritime',
#   'toefl'],
#  ['vocabulary',
#   'first',
#   'istanbul',
#   'wireless sensor network',
#   'interdisciplinary',
#   'motivating',
#   'still uni',
#   'im still learning english already teach student starting first class'],
#  ['pe',
#   'k12 alignment',
#   'pyp',
#   'orthodontics',
#   'orthodontics',
#   'discussion club',
#   'control',
#   'informática',
#   'pyp inquiry mhillsed kinderchat pypchat'],
#  ['html',
#   'music',
#   '13',
#   'drama',
#   'computer gaming history science musicpercussion audiovisual movieproduction greenscreen',
#   'moodle',
#   'sustainability',
#   'literarcy',
#   'drama science literarcy music',
#   'vocal',
#   'vocal music',
#   'emotional intelligence',
#   'moodle technology itc basic eletronics network access html'],
#  ['funções',
#   'matemática financeira',
#   'informatics',
#   'isarel',
#   'dimensional metrology',
#   'modelling',
#   'geometrical metrology',
#   'composition',
#   'product',
#   'itsupport',
#   'cooking',
#   'reliever',
#   'relief',
#   'syndrome',
#   'mexico'],
#  ['technonoly',
#   'spanish',
#   'adult',
#   'roman',
#   'spanish conversation',
#   '155',
#   'programming',
#   'principal',
#   'geology',
#   'dyslexia',
#   'roman',
#   'teaching young adult',
#   'pbl',
#   'young adult',
#   'class follow traditional teaching design use technology practically inexistent except video downloaded tube',
#   'acl',
#   'salwan'],
#  ['heat temperature',
#   'microbiology',
#   'heat',
#   'conjuntos',
#   'algorithm',
#   'chromebooks',
#   'safety',
#   'kzjl',
#   'hot potato',
#   'microcontrollers',
#   'processing'],
#  ['mathemicas',
#   'comunication',
#   'building performance simulation',
#   'simulation',
#   'tecnology',
#   'instrumentalenglish',
#   'mindmapping',
#   '11math',
#   'katialucia'],
#  ['novel',
#   'reading',
#   'graphic novel',
#   'emerging reading skill',
#   'smartboard',
#   'graphic',
#   'sacred female training',
#   'k7',
#   'great man theory',
#   'exam',
#   'guided reading',
#   '91287',
#   'graphic novel',
#   'basic'],
#  ['language',
#   'russian language',
#   'second language writing',
#   'language',
#   'second language',
#   'spirituality',
#   'english second language',
#   'second language',
#   'second language speaker',
#   'microscopy',
#   'vernacular language',
#   'constructivism',
#   'english second language',
#   'factorizacion limites',
#   'german second language',
#   'second language reading',
#   'english second language',
#   'title',
#   'dista',
#   'musicology',
#   'cognitive musicology',
#   'radio',
#   'advocacy',
#   'language',
#   'second language acquisition'],
#  ['digital system design',
#   'design',
#   'instructional design',
#   'instructional design technology',
#   'digital circuit design',
#   'cte',
#   'français',
#   'digital design',
#   'electronic preparation'],
#  ['primary',
#   'autocad',
#   'primary teacher',
#   'pre primary',
#   'early childhood education',
#   'agronomy',
#   'primary',
#   'teacher education',
#   'teacher',
#   'painting',
#   'teacher pd',
#   'portuguese',
#   'celta',
#   'celta teacher',
#   'childhood education'],
#  ['world religion',
#   'speaking',
#   'languagedevelopment',
#   'weather',
#   'greek',
#   'religion',
#   'creativity',
#   'process',
#   'creativity',
#   'process expectation',
#   'icdl',
#   'weather climate',
#   'philosophy',
#   'greek',
#   'snap',
#   'free open source software'],
#  ['property matter',
#   'structure property matter',
#   'matter',
#   'internet',
#   'northern canada',
#   'phonics',
#   'behaviour',
#   'boston',
#   '1',
#   'canada alberta',
#   'canada',
#   'autonomous behaviour',
#   'internet thing'],
#  ['fraction',
#   'nursing',
#   'periodic table',
#   'feedback',
#   '0',
#   'comprehension',
#   'figure',
#   'nursing ethic philosphy',
#   'spatial reasoning',
#   'dis',
#   'interdisciplinarity',
#   'ceramic',
#   'anthropology',
#   'nonetheless',
#   'pathophysiology',
#   'mentoring',
#   'want learn design lesson based use different technology stimulate critical thinking among student',
#   'computing',
#   'learn play',
#   'organic synthesis'],
#  ['cs',
#   'assessment',
#   'mixture',
#   'lego',
#   'ng',
#   'english lingua franca',
#   'mastery based assessment',
#   'ell',
#   'python',
#   'climate change',
#   'standard based assessment',
#   'classgym',
#   'standard based objective assessment',
#   'application'],
#  ['anathomy',
#   'mysql',
#   'educator',
#   'home automation system',
#   'gafe',
#   'smar nearpod gafe cgi 11ipads',
#   '3d printing',
#   'conversation',
#   'gafe',
#   'density functional theory'],
#  ['neuro',
#   'community college',
#   'environmentalplanning',
#   'lessonplans activity listeningexercises pronunciation practicalideas',
#   'activity',
#   'water',
#   'college',
#   'finance',
#   'college',
#   'software',
#   'ecdl',
#   'pronunciation',
#   'finance',
#   'distance',
#   'islam',
#   'selfdesign',
#   'textbookeditor',
#   'create flow'],
#  ['solution solubility',
#   'hospitality',
#   'jk',
#   'brainbased',
#   'epistemology',
#   'fishery wildlife',
#   'virology',
#   'mapskills'],
#  ['chemical calculation',
#   'microsoft office',
#   'grammar',
#   'chemical system equilibrium',
#   'hand',
#   'laptop',
#   'plickers',
#   'librarian',
#   'slowmathchat',
#   'adaptation',
#   'augmented reality',
#   'endodontics',
#   'chemical reaction calculation'],
#  ['ecological literacy',
#   '6',
#   'ap physic c',
#   'literacy',
#   'ela',
#   'literacy',
#   'invention inventor',
#   'low lexile',
#   'tectonic plate',
#   'portafolio',
#   'ap csp',
#   'pypc',
#   'low literacy',
#   'solidgeometry',
#   'vernier'],
#  ['best practice',
#   'chile',
#   'math',
#   'math',
#   'thinking',
#   'math',
#   'value',
#   'visual thinking',
#   'math basique',
#   'linux',
#   'thinking box',
#   'singapore math'],
#  ['structure',
#   'interactive',
#   'bilingual',
#   'decisionmaking',
#   'interactive classroom setting',
#   'prac'],
#  ['practical', 'kindergarten', 'linguistics', 'comedy', 'teen', 'biolo'],
#  ['number',
#   'embed code',
#   'immigration',
#   'evolution',
#   'data',
#   'car',
#   'cairo egypt',
#   'book',
#   'ebooks',
#   'japanese',
#   'data analytics',
#   'big data',
#   'gu',
#   'population',
#   'didatic book',
#   'egypt'],
#  ['area',
#   'area measurement',
#   'measurement',
#   'efl',
#   'polish',
#   '4',
#   'machine',
#   'intervention',
#   'simple machine',
#   'elt',
#   'instructionalcoach',
#   'performance',
#   'efl',
#   'prototyping'],
#  ['engineering',
#   'sk',
#   'photography',
#   'folksonomic',
#   'medium engineering',
#   'medium',
#   'agricultural engineering',
#   'medium competence'],
#  ['system',
#   '10',
#   'eighth grade',
#   '9',
#   'semantics',
#   'advanced instrumentation system',
#   'biomedical instrumentation',
#   'grade 9 biology',
#   'observation',
#   'algebra',
#   'algebra',
#   'eca',
#   '5th grade',
#   'heritage',
#   'grade 10 science',
#   'disease',
#   'educacion infantil',
#   'grade 9',
#   'grade 9 chemistry',
#   'grade 10 chemistry',
#   '202',
#   'pensamento computacional'],
#  ['hiv',
#   'electricity magnetism',
#   'electricity',
#   'addition without carry',
#   'develop',
#   'addition',
#   'construction',
#   'central role',
#   'grade5 mathematic',
#   'magnetism',
#   'bio',
#   'facebook',
#   'biocomp',
#   'ele'],
#  ['stem',
#   'linear relation',
#   'limit',
#   'combination class',
#   'languagearts',
#   'hebrew',
#   '2244',
#   'nonformal',
#   'globalization',
#   'brazil',
#   'hydroponics',
#   'electrostatics',
#   'routing'],
#  ['time telling',
#   'intuition',
#   'acid base',
#   'editing',
#   'dan meyer',
#   'roleplays',
#   'diseño',
#   'eletricity',
#   'homeschooling',
#   'tradition',
#   'heba']]
